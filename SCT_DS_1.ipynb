# %%
# !pip install pandas matplotlib openpyxl

# %%
import pandas as pd
file_path='/content/API_SP.POP.TOTL_DS2_en_excel_v2_38348.xls'
data = pd.read_excel(file_path, sheet_name='Data', skiprows=3)
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %% [markdown]
# **Filtering relevant columns**

# %%
pop_2022 = data[['Country Name', '2022']].dropna()
pop_2022 = pop_2022.sort_values(by='2022' , ascending=False).head(10)
pop_2022
# Out:
#                    Country Name          2022
# 259                       World  7.990400e+09
# 103            IDA & IBRD total  6.795050e+09
# 140         Low & middle income  6.438272e+09
# 156               Middle income  5.846791e+09
# 102                   IBRD only  4.928522e+09
# 62   Early-demographic dividend  3.470645e+09
# 139         Lower middle income  3.043358e+09
# 249         Upper middle income  2.803432e+09
# 63          East Asia & Pacific  2.379648e+09
# 142   Late-demographic dividend  2.324126e+09

# %% [markdown]
# **Creating Bar Chart**

# %%
import matplotlib.pyplot as plt
plt.bar(pop_2022['Country Name'], pop_2022['2022'] , color='skyblue')
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Top 10 Countries with Highest Population in 2022')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
